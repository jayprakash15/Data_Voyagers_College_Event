# %%
import pandas as pd
import numpy as np

# %%
Data = pd.read_csv("D:\College\MSc (Christ University)\Hackthon\Data Voygers Details\Dataset\Student_Scores_Dataset.csv")
Data.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
Data.shape
# Out:
# (30641, 15)

# %%
Data.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
Data = Data.dropna()
Data.shape
# Out:
# (19243, 15)

# %%
# This code is to drop column
#X = df.drop(["case", "site", "Pop", "sex", "age"], axis=1)
#y = df["age"]

# %%
# This code is to drop NA's from specific column
Data_New = Data.dropna(subset=['ParentEduc','WklyStudyHours'])
Data_New.shape
# Out:
# (27903, 15)

# %%
Data_New.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1662
# ParentEduc                0
# LunchType                 0
# TestPrep               1674
# ParentMaritalStatus    1086
# PracticeSport           564
# IsFirstChild            822
# NrSiblings             1436
# TransportMeans         2848
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [raw]
# Data.to_csv('Student_Scores_Dataset.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(Data, x='WritingScore')
# Out:
# <AxesSubplot: xlabel='WritingScore', ylabel='Count'>

# %%
sns.histplot(Data, x='ReadingScore')
# Out:
# <AxesSubplot: xlabel='ReadingScore', ylabel='Count'>

# %%
sns.histplot(Data, x='MathScore')
# Out:
# <AxesSubplot: xlabel='MathScore', ylabel='Count'>

# %%
sns.pairplot(Data,vars=['MathScore','ReadingScore','WritingScore'],hue='Gender')

# %%
Data["WklyStudyHours"].unique()
# Out:
# array(['< 5', '5 - 10', '> 10'], dtype=object)

# %%
sns.pairplot(Data,vars=['MathScore','ReadingScore','WritingScore'],hue='WklyStudyHours')

# %%
sns.pairplot(Data,vars=['MathScore','ReadingScore','WritingScore'],hue='LunchType')

# %%
sns.pairplot(Data,vars=['MathScore','ReadingScore','WritingScore'],hue='PracticeSport')

# %%
Data["ParentMaritalStatus"].value_counts()
# Out:
# married     11009
# single       4608
# divorced     3256
# widowed       370
# Name: ParentMaritalStatus, dtype: int64

# %% [raw]
# #Data_New = Data
# Data_New = Data[Data["ParentMaritalStatus"].isna()=="False"]
# Data_New = Data[Data["WklyStudyHours"].isna()=="False"]
# Data_New

# %% [raw]
# Data_New = Data[["MathScore','ReadingScore','WritingScore','WklyStudyHours","ParentMaritalStatus"]]

# %%
Data_New = Data[Data["WklyStudyHours"] == '> 10']
Data_New["ParentMaritalStatus"].value_counts()
# Out:
# married     1944
# single       777
# divorced     581
# widowed       61
# Name: ParentMaritalStatus, dtype: int64

# %%
Data["ParentMaritalStatus"].value_counts()
# Out:
# married     11009
# single       4608
# divorced     3256
# widowed       370
# Name: ParentMaritalStatus, dtype: int64

# %%
Data_New["ParentEduc"].value_counts()
# Out:
# some college          781
# some high school      667
# associate's degree    663
# high school           635
# bachelor's degree     373
# master's degree       244
# Name: ParentEduc, dtype: int64

# %%
Data["ParentEduc"].value_counts()
# Out:
# some college          4425
# high school           3773
# associate's degree    3749
# some high school      3658
# bachelor's degree     2293
# master's degree       1345
# Name: ParentEduc, dtype: int64

# %%
#Data_New.isnull().sum()
ParentEduc = []
for r in Data_New["ParentEduc"]:
    x = str(r).replace('high school','some high school')
    x = str(r).replace("College",'some college')
    x = str(r).replace("College","associate's degree")
    x = str(r).replace("College","bachelor's degree")
    x = str(r).replace("College","master's degree")
    ParentEduc.append(x)
ParentEduc
# Out:
# ['some college',
#  'high school',
#  'some college',
#  "bachelor's degree",
#  'some college',
#  "associate's degree",
#  'some high school',
#  'some college',
#  'some high school',
#  "associate's degree",
#  "associate's degree",
#  "associate's degree",
#  'some high school',
#  'high school',
#  "bachelor's degree",
#  'some college',
#  'some college',
#  "associate's degree",
#  "master's degree",
#  'high school',
#  "associate's degree",
#  'some college',
#  'some high school',
#  "bachelor's degree",
#  "associate's degree",
#  'some college',
#  'some high school',
#  "associate's degree",
#  "associate's degree",
#  "associate's degree",
#  "associate's degree",
#  "associate's degree",
#  'high school',
#  'some college',
#  "associate's degree",
#  'high school',
#  "associate's degree",
#  "bachelor's degree",
#  "bachelor's degree",
#  'some high school',
#  'some college',
#  'some high school',
#  'some high school',
#  'some high school',
#  'some college',
# ...

# %%
#ParentEduc.unique()

# %%
Data_New["ParentEduc"] = ParentEduc
Data_New["ParentEduc"].unique()
# Out:
# C:\Users\jaypr\AppData\Local\Temp\ipykernel_7476\3560595091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_New["ParentEduc"] = ParentEduc
# array(['some college', 'high school', "bachelor's degree",
#        "associate's degree", 'some high school', "master's degree"],
#       dtype=object)

# %%
plt.figure(figsize = (15,7))
sns.countplot(x= "ParentEduc", data= Data_New)
# Out:
# <AxesSubplot: xlabel='ParentEduc', ylabel='count'>

# %%
plt.figure(figsize = (15,7))
sns.countplot(x= "ParentMaritalStatus", data= Data_New)
# Out:
# <AxesSubplot: xlabel='ParentMaritalStatus', ylabel='count'>

# %%
plt.figure(figsize = (15,7))
sns.countplot(x= "EthnicGroup", data= Data)
# Out:
# <AxesSubplot: xlabel='EthnicGroup', ylabel='count'>
